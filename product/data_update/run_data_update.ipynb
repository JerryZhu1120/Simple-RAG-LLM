# %% [markdown]
# ## Run Data Update
#
# test each backend component

# %% [markdown]
# #### Data Update

# %%
from data_update import DataUpdate
data_update_instance = DataUpdate('../config.json')
# company_list = ['TSM.N']
# # 9984.T 7203.T 4911.T 6594.T 8316.T 8411.T 8035.T 6758.T 8591.T "0027.HK",
version = 1130
data_update_instance.update_all(version=version,force_skip=True,batch_size=80)
# Out:
# 1525
# Warning: Path '../data/7267.T_1130' exists, re-collect data again.
# Will download to: ../data/7267.T_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 12
# transcripts num_docs: 0
# Press Releases num_docs: 0
# news num_docs: 47
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 100%|██████████| 12/12 [00:00<00:00, 111600.11it/s]
# - document mq_bcd30b49-74ff-47cd-8394-9e892df9ab32 is absent or already exists, skip it
# - document mq_d88fd1a2-8b9d-4e5c-9378-2efd879f6fa5 is absent or already exists, skip it
# - document jpmorgan_GPS-4497254-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4497226-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4493260-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4486161-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4521804-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4521801-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4526942-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4526935-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4525629-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4525773-0 is absent or already exists, skip it
# 100%|██████████| 47/47 [00:00<00:00, 202186.96it/s]
# - document yahoo_4759d230-d98d-3945-89a2-d06a709e1fa4 already exists, skip it
# - document yahoo_3e6e248b-d6cd-315e-97cc-71fead3b99f9 already exists, skip it
# - document yahoo_b6fb5057-c43a-304d-a3d2-cf2b720c62b6 already exists, skip it
# - document yahoo_72eefbde-b01e-3ad0-b36b-d4143b0f9632 already exists, skip it
# - document yahoo_76d547ba-a65b-342a-98ed-7f6526e1ea79 already exists, skip it
# - document yahoo_a4825e8e-5153-3407-beb8-2f291461d71d already exists, skip it
# - document yahoo_bbada500-6dcc-3f92-a8e4-96e647757be7 already exists, skip it
# - document yahoo_180f2925-e63e-3754-93cc-9b39e3149e7b already exists, skip it
# - document yahoo_1d5be673-7ef3-399c-ac76-8dd202add62c already exists, skip it
# - document yahoo_f8ac7ee5-a1e0-377c-855d-03a875e04494 already exists, skip it
# - document yahoo_fdd16b36-d2e1-3b55-8a73-e968916ca9e3 already exists, skip it
# - document yahoo_42c87cd5-32a2-3b77-8a5e-23b17f3ec444 already exists, skip it
# - document yahoo_25da4bad-544b-3f9c-9fda-bf16d879dae1 already exists, skip it
# - document yahoo_ccce55bd-d9e3-304f-8081-a0e3de228d00 already exists, skip it
# - document yahoo_808f6e2b-6336-4d2c-aa13-9fc5e023f6eb already exists, skip it
# - document yahoo_409bea65-879e-3164-84c4-b5b672e9d645 already exists, skip it
# - document yahoo_1de775ce-eb63-33d9-ad91-6b6f966e4353 already exists, skip it
# - document yahoo_055e63fa-f3f1-344f-85dc-fbb3c8ed4948 already exists, skip it
# - document nikkei_DGXZQOUC21A1P0R20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUC211XQ0R20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUC208DJ0Q3A920C2000000 already exists, skip it
# - document nikkei_DGXZTSJD10601_Q3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS15_Z10C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS14_Z10C23A9000000 already exists, skip it
# - document nikkei_DGXZASFL19HUI_Z10C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS12_Z10C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS11_Z10C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUC267Q70W3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOUC2642J0W3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS13_X20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS11_X20C23A9000000 already exists, skip it
# - document nikkei_DGXZASFL27H7Q_X20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUC2867I0Y3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOUC284M90Y3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOUC286SY0Y3A920C2000000 already exists, skip it
# - document nikkei_DGXZASFL30H01_Q3A930C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS12_Z20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUC023KW0S3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUC0530T0V01C23A0000000 already exists, skip it
# - document nikkei_DGXZQOCC052LM0V01C23A0000000 already exists, skip it
# - document nikkei_DGXZQOCC059Y80V01C23A0000000 already exists, skip it
# - document nikkei_DGXZQOUC080JD0Y3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOCC104Y30Q3A011C2000000 already exists, skip it
# - document nikkei_DGXZQOGM107CX0Q3A011C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS14_R11C23A0000000 already exists, skip it
# - document nikkei_DGXZQOUC061MF0W3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUC122X10S3A011C2000000 already exists, skip it
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Warning: Path '../data/7974.T_1130' exists, re-collect data again.
# Will download to: ../data/7974.T_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 13
# transcripts num_docs: 0
# Press Releases num_docs: 0
# news num_docs: 12
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 100%|██████████| 13/13 [00:00<00:00, 52378.44it/s]
# - document bt_178381 is absent or already exists, skip it
# - document ubs_300663305 is absent or already exists, skip it
# - document ubs_300663303 is absent or already exists, skip it
# - document jf_395767 is absent or already exists, skip it
# - document jf_397820 is absent or already exists, skip it
# - document jpmorgan_GPS-4513457-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4513322-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4505151-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4505147-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4526889-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4524920-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4531435-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4531434-0 is absent or already exists, skip it
# 100%|██████████| 12/12 [00:00<00:00, 43501.86it/s]
# - document yahoo_9b314cb8-3380-39e2-94c5-d96d4f8d9326 already exists, skip it
# - document yahoo_b1a2e92f-4323-322b-93e4-bcbfd6b0d326 already exists, skip it
# - document yahoo_c6613ed0-b967-45d0-a05a-240c7910cd25 already exists, skip it
# - document yahoo_bfc178f1-f396-391b-901e-e7a950f4d991 already exists, skip it
# - document nikkei_DGXZQOUF2068P0Q3A920C2000000 already exists, skip it
# - document nikkei_DGXZASFL20HYV_Q3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS15_Q3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOUC228AT0S3A920C2000000 already exists, skip it
# - document nikkei_DGXZASFL03HVU_T01C23A0000000 already exists, skip it
# - document nikkei_DGXZQOUC042510U3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUF122D20S3A011C2000000 already exists, skip it
# - document nikkei_DGXZQOUC120VE0S3A011C2000000 already exists, skip it
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Warning: Path '../data/6752.T_1130' exists, re-collect data again.
# Will download to: ../data/6752.T_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 14
# transcripts num_docs: 0
# Press Releases num_docs: 0
# news num_docs: 21
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 100%|██████████| 14/14 [00:00<00:00, 46901.16it/s]
# - document mq_f04560c1-bf19-4d73-ad57-966d3bc686bd is absent or already exists, skip it
# - document mq_e18b4005-ba3b-4fd5-9a72-41845e6b3b38 is absent or already exists, skip it
# - document mq_8f9e5a35-86cb-418a-8d37-854cd4c27b83 is absent or already exists, skip it
# - document mq_40d658d7-2bf6-42d8-be7f-786dc9c0be71 is absent or already exists, skip it
# - document mq_d89e1414-c078-4371-8bfd-8e09c8a43aff is absent or already exists, skip it
# - document mq_74c49ea1-2152-4863-a752-d67532de8690 is absent or already exists, skip it
# - document mq_6603fea1-e289-4e76-b507-baf67f4428d2 is absent or already exists, skip it
# - document mq_15a421cc-190c-497e-9128-b1d0f69eb10a is absent or already exists, skip it
# - document jf_388346 is absent or already exists, skip it
# - document jpmorgan_GPS-4497571-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4496540-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4465498-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4528961-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4528548-0 is absent or already exists, skip it
# 100%|██████████| 21/21 [00:00<00:00, 59154.05it/s]
# - document yahoo_ab749d55-54e7-31ac-9356-2e2e41f0a39a already exists, skip it
# - document yahoo_473084ac-01c5-30a8-8c77-8dd1633258fb already exists, skip it
# - document yahoo_f06ca4bf-fb33-354a-918b-577958ede2cd already exists, skip it
# - document yahoo_bf427c22-d4fa-3e61-9f66-5933e0eaca30 already exists, skip it
# - document yahoo_fae0c18b-7260-34d0-9ee8-d6d856a1d5ce already exists, skip it
# - document yahoo_b221144a-0ebf-32ad-8e65-40ba53db9d2c already exists, skip it
# - document yahoo_51e8fe3e-5cab-3144-8393-e24cad96aa1b already exists, skip it
# - document nikkei_DGXZQOUF21CWV0R20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUC251PW0V20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOCC211YQ0R20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUA289DS0Y3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOUF2880P0Y3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOUF29CJO0Z20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUF025EY0S3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUF027F40S3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUC0329G0T01C23A0000000 already exists, skip it
# - document nikkei_DGXZQOUC26C080W3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOUF1147H0R11C23A0000000 already exists, skip it
# - document nikkei_DGXZQOUF125E40S3A011C2000000 already exists, skip it
# - document nikkei_DGXZQOUF123CA0S3A011C2000000 already exists, skip it
# - document nikkei_DGXZQOUF114Z70R11C23A0000000 already exists, skip it
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Warning: Path '../data/8306.T_1130' exists, re-collect data again.
# Will download to: ../data/8306.T_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 5
# transcripts num_docs: 0
# Press Releases num_docs: 0
# news num_docs: 34
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 100%|██████████| 5/5 [00:00<00:00, 22429.43it/s]
# - document mq_e4eb3eb5-3605-4056-9175-bade7626b765 is absent or already exists, skip it
# - document jpmorgan_GPS-4510949-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4484696-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4531873-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4528728-0 is absent or already exists, skip it
# 100%|██████████| 34/34 [00:00<00:00, 74429.19it/s]
# - document yahoo_d8a475c7-5cd1-3bd6-ae33-ace2430442f7 already exists, skip it
# - document yahoo_4ad2766a-a86f-3e8f-9125-6f01430c9de4 already exists, skip it
# - document yahoo_13a35771-56c6-3837-a7cf-2e0873d6cc53 already exists, skip it
# - document yahoo_d51ddb97-675b-3b01-a248-7ecad2ac596c already exists, skip it
# - document yahoo_67ef5368-2ec4-31d1-8f95-ce7b1a00eebe already exists, skip it
# - document yahoo_2504dd02-65fb-330c-86fb-14375585cbf3 already exists, skip it
# - document yahoo_64c9483e-c256-3737-8af3-5ef6caf0c103 already exists, skip it
# - document yahoo_fdf4fa16-82bf-3caa-aa0d-defb3405b15d already exists, skip it
# - document yahoo_c9fdba6f-ed1c-377f-972b-0339492f6ca3 already exists, skip it
# - document yahoo_591fd444-4b70-32e9-bab4-f3257500e6b5 already exists, skip it
# - document yahoo_a7e9883a-2566-396b-a209-0121f27d20f5 already exists, skip it
# - document yahoo_f9bb42aa-ba67-3bfe-9176-b30109be38db already exists, skip it
# - document nikkei_DGXZQOUB00003_R20C23A9000000 already exists, skip it
# - document nikkei_DGXZASFL21I01_R20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS16_R20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS15_R20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS14_R20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS13_R20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS12_R20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS11_R20C23A9000000 already exists, skip it
# - document nikkei_DGXZASFL21H2V_R20C23A9000000 already exists, skip it
# - document nikkei_DGXZASFL20HA7_Q3A920C2000000 already exists, skip it
# - document nikkei_DGXZASFL19HWA_Z10C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUB00003_Z10C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS16_Z10C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS13_Z10C23A9000000 already exists, skip it
# - document nikkei_DGXZASFL19HO3_Z10C23A9000000 already exists, skip it
# - document nikkei_DGXZASFL22H2E_S3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOGN2601Q0W3A920C2000000 already exists, skip it
# - document nikkei_DGXZASFL26HUV_W3A920C2000000 already exists, skip it
# - document nikkei_DGXZASFL02HW4_S3A001C2000000 already exists, skip it
# - document nikkei_DGXZASFL03HVW_T01C23A0000000 already exists, skip it
# - document nikkei_DGXZNSD5ICP05_W3A001C2000000 already exists, skip it
# - document nikkei_DGXZNSD5ISB05_W3A001C2000000 already exists, skip it
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Warning: Path '../data/9984.T_1130' exists, re-collect data again.
# Will download to: ../data/9984.T_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 14
# transcripts num_docs: 0
# Press Releases num_docs: 0
# news num_docs: 48
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 100%|██████████| 14/14 [00:00<00:00, 26739.64it/s]
# - document jf_385301 is absent or already exists, skip it
# - document jf_384591 is absent or already exists, skip it
# - document jf_384433 is absent or already exists, skip it
# - document jf_382390 is absent or already exists, skip it
# - document jpmorgan_GPS-4497524-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4518060-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4517743-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4518235-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4523014-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4533054-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4550518-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4549297-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4572073-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4571065-0 is absent or already exists, skip it
# 100%|██████████| 48/48 [00:00<00:00, 57243.84it/s]
# - document yahoo_8c4726f3-8db9-3f3a-bf26-b438a2eb3c3a already exists, skip it
# - document yahoo_ed52c7d8-3549-31f2-8d1b-0f16b51ebdeb already exists, skip it
# - document yahoo_e1226869-31d3-32dc-819e-a872d326f7d3 already exists, skip it
# - document yahoo_52456e17-0106-31a5-935a-c344adda22b6 already exists, skip it
# - document yahoo_0dddfb0c-bc58-3c95-a0d7-051b18d1373c already exists, skip it
# - document yahoo_45231f22-097a-3dde-ae0e-6d0f5dbd3c21 already exists, skip it
# - document yahoo_0dee790c-9c01-3eb9-8b84-12fdd2e44ed2 already exists, skip it
# - document yahoo_d202e909-57d1-364c-bc34-6cc8c20ff492 already exists, skip it
# - document yahoo_5cb4302c-32b3-3187-be25-6082c54a8577 already exists, skip it
# - document yahoo_e4971c73-58b4-3b35-bb9b-8823959f0abc already exists, skip it
# - document yahoo_f6eb950a-2f2c-3812-bdbe-ee1bebb57968 already exists, skip it
# - document yahoo_1d807697-83de-38ff-8d49-9169d82bfc65 already exists, skip it
# - document yahoo_d454ae00-14b8-3df3-b7f9-c23a573650ca already exists, skip it
# - document yahoo_3919963f-7868-39d4-8be0-f64ef429e5d1 already exists, skip it
# - document yahoo_9c3639b2-b02a-3ae1-a5b0-77aa4626fed2 already exists, skip it
# - document yahoo_ea19ed59-e52c-3a3d-9051-21e731b8b39d already exists, skip it
# - document yahoo_c885f0c7-4763-3816-8ba8-4443b1b257d2 already exists, skip it
# - document yahoo_77609277-8434-4622-833c-fc0185a42190 already exists, skip it
# - document yahoo_1278ac51-c2f1-30d9-b9d9-cdee3d41fe78 already exists, skip it
# - document yahoo_86d75772-6f16-3d45-9803-053bb9d9fa08 already exists, skip it
# - document yahoo_2757d041-569e-30e7-bdd3-2f42bdbd61b2 already exists, skip it
# - document yahoo_461ffa43-56fe-39e3-98e1-8c5ac0f4d343 already exists, skip it
# - document yahoo_8b59839a-13ad-3c1d-9730-1c6aa9cd37dc already exists, skip it
# - document yahoo_23959619-2bf1-3a20-adbf-9dac62c82832 already exists, skip it
# - document yahoo_9a0b7927-de36-3921-83d8-0b8e9cf609c3 already exists, skip it
# - document yahoo_61413658-c039-3305-9cc8-ce7a1f1ee876 already exists, skip it
# - document yahoo_84b7ee84-fa76-3869-be75-744fbf9a46eb already exists, skip it
# - document yahoo_b883a1e1-1765-3a7b-bf97-95a9e45f3690 already exists, skip it
# - document yahoo_f19c36d6-08e7-33fe-8e40-4a0c1182e76f already exists, skip it
# - document nikkei_DGXZASFL22HDQ_S3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS11_S3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOGN21DVD0R20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS16_S3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOUC256FU0V20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUC2796N0X20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS15_X20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUC285ZZ0Y3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOGN286SI0Y3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOUC203CJ0Q3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOUC2727K0X20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS16_S3A001C2000000 already exists, skip it
# - document nikkei_DGXZASFL02HBA_S3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUC042S20U3A001C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS11_T01C23A0000000 already exists, skip it
# - document nikkei_DGXZQOUC033SR0T01C23A0000000 already exists, skip it
# - document nikkei_DGXZQOUC043200U3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUC1010V0Q3A011C2000000 already exists, skip it
# - document nikkei_DGXZQOUC106KM0Q3A011C2000000 already exists, skip it
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Warning: Path '../data/7203.T_1130' exists, re-collect data again.
# Will download to: ../data/7203.T_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 25
# transcripts num_docs: 0
# Press Releases num_docs: 0
# news num_docs: 55
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 100%|██████████| 25/25 [00:00<00:00, 77385.68it/s]
# - document ubs_300662863 is absent or already exists, skip it
# - document ubs_300662862 is absent or already exists, skip it
# - document ubs_300663304 is absent or already exists, skip it
# - document ubs_300663299 is absent or already exists, skip it
# - document mq_847bbb18-2c44-4d82-8112-7c19d00759e1 is absent or already exists, skip it
# - document mq_afb5cede-8589-45e4-b117-c8e33e15d520 is absent or already exists, skip it
# - document mq_4dea1cdb-4258-47fa-955c-c943d98c83c7 is absent or already exists, skip it
# - document mq_cec0294b-3982-4535-b2be-fd66ab5b5e16 is absent or already exists, skip it
# - document mq_c70dee93-a820-42cb-aa04-300540f9a55b is absent or already exists, skip it
# - document jf_388482 is absent or already exists, skip it
# - document jpmorgan_GPS-4505064-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4504059-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4504044-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4503982-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4503940-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4518992-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4518994-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4523785-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4525602-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4525601-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4527498-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4527495-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4523799-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4532672-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4532655-0 is absent or already exists, skip it
# 100%|██████████| 55/55 [00:00<00:00, 87216.15it/s]
# - document yahoo_e8e7ccf4-df72-385e-8ef1-774b6abf76be already exists, skip it
# - document yahoo_97179c67-b470-37bd-8162-88e8d25442fe already exists, skip it
# - document yahoo_cec5377c-9a82-3339-a463-4fbe3fb20085 already exists, skip it
# - document yahoo_2541d5b4-03b6-3909-ab3d-99af9b1f4501 already exists, skip it
# - document yahoo_24627d22-101d-39d1-aed4-79d167b64b0b already exists, skip it
# - document yahoo_3e283cc1-4998-3001-b0fc-9cbc45757dec already exists, skip it
# - document yahoo_435da2a1-4cc2-39ce-9ba7-54c7778dd53f already exists, skip it
# - document yahoo_d6ae303d-d09e-312a-81ec-4e9697169845 already exists, skip it
# - document yahoo_3eda9b61-7315-333c-9030-3e901c7031b4 already exists, skip it
# - document yahoo_a52523b3-d809-385a-a942-ac9caf0cac4c already exists, skip it
# - document yahoo_95eae55d-96c1-303c-9fb2-f7ceb8cfdb6b already exists, skip it
# - document yahoo_1d0dea3a-ad5d-3bf4-8bc0-e7d599b99397 already exists, skip it
# - document yahoo_8b346bdc-7d3d-3050-9092-e0402a46f4a8 already exists, skip it
# - document yahoo_61d6a96f-2f4d-3ed6-93cb-d924cd5b39b7 already exists, skip it
# - document yahoo_ac2880d0-093e-3cbb-a7ad-617ddcf07db6 already exists, skip it
# - document yahoo_40d37fe9-a9e4-3e6b-bf15-f48cd1ff87ae already exists, skip it
# - document yahoo_9d0057bc-12d9-34c5-8596-cc59217d9b86 already exists, skip it
# - document yahoo_de936a32-52c1-3591-8119-2295976492f5 already exists, skip it
# - document yahoo_8559067b-a4af-3a18-80c0-a814c7c087f3 already exists, skip it
# - document yahoo_543a8d8f-1e53-3471-a0e2-8fdd6ae6bc15 already exists, skip it
# - document yahoo_92600e7b-f7c9-3386-bb61-6c1a16f2a413 already exists, skip it
# - document yahoo_b03bf419-42e1-3045-a17f-9a13afdb9008 already exists, skip it
# - document yahoo_ce7cf8d9-6832-3397-9ef7-647de784bdb9 already exists, skip it
# - document yahoo_e814dd32-3dfa-3178-ad5c-1cb3f2528813 already exists, skip it
# - document yahoo_6ade3455-1744-3c5d-aa92-9deda6fe72a3 already exists, skip it
# - document yahoo_f90c2450-bded-38a4-8cc0-b44d5c74f42b already exists, skip it
# - document yahoo_cac93d35-6557-3d71-beb9-22e209f28e8e already exists, skip it
# - document yahoo_432e3e55-b5c7-3280-af0e-7f6fd3137276 already exists, skip it
# - document yahoo_6fb81bdb-d894-30bd-9997-6d9d2db95103 already exists, skip it
# - document yahoo_bb439750-835d-4e75-95de-f76bbb128332 already exists, skip it
# - document yahoo_ec8eb3b7-9eb7-3201-b91c-df625c3edf3d already exists, skip it
# - document yahoo_8d6a3ffb-6fc9-3895-b1a6-d796f00d63c7 already exists, skip it
# - document nikkei_DGXZTSJD20101_R20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUC228LQ0S3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS14_S3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOFH231850T20C23A9000000 already exists, skip it
# - document nikkei_DGXZTSJS70301_W3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOCC13CHA0T10C23A9000000 already exists, skip it
# - document nikkei_DGXZQOCC013210R01C23A0000000 already exists, skip it
# - document nikkei_DGXZQOCC025FE0S3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUC024040S3A001C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS13_S3A001C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS12_S3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUA052BM0V01C23A0000000 already exists, skip it
# - document nikkei_DGXZASS0ISS15_V01C23A0000000 already exists, skip it
# - document nikkei_DGXZQOFD059KY0V01C23A0000000 already exists, skip it
# - document nikkei_DGXZQOCC0648D0W3A001C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS12_W3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUE069GL0W3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOFD117JM0R11C23A0000000 already exists, skip it
# - document nikkei_DGXZQOGM1137N0R11C23A0000000 already exists, skip it
# - document nikkei_DGXZQOFD122OQ0S3A011C2000000 already exists, skip it
# - document nikkei_DGXZQOFD126J90S3A011C2000000 already exists, skip it
# - document nikkei_DGXZASFL12HLS_S3A011C2000000 already exists, skip it
# - document nikkei_DGXZQOUC101GI0Q3A011C2000000 already exists, skip it
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Warning: Path '../data/4911.T_1130' exists, re-collect data again.
# Will download to: ../data/4911.T_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 28
# transcripts num_docs: 0
# Press Releases num_docs: 0
# news num_docs: 4
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 100%|██████████| 28/28 [00:00<00:00, 42229.60it/s]
# - document bt_177299 is absent or already exists, skip it
# - document bt_177102 is absent or already exists, skip it
# - document bt_176410 is absent or already exists, skip it
# - document bt_176217 is absent or already exists, skip it
# - document bt_176044 is absent or already exists, skip it
# - document bt_175971 is absent or already exists, skip it
# - document bt_183748 is absent or already exists, skip it
# - document ubs_300659023 is absent or already exists, skip it
# - document ubs_300658912 is absent or already exists, skip it
# - document ubs_300661017 is absent or already exists, skip it
# - document ubs_300661016 is absent or already exists, skip it
# - document ubs_300660387 is absent or already exists, skip it
# - document ubs_300660386 is absent or already exists, skip it
# - document ubs_300660036 is absent or already exists, skip it
# - document ubs_300660029 is absent or already exists, skip it
# - document ubs_300662053 is absent or already exists, skip it
# - document ubs_300662052 is absent or already exists, skip it
# - document jf_393347 is absent or already exists, skip it
# - document jf_392736 is absent or already exists, skip it
# - document jpmorgan_GPS-4500755-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4505270-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4505052-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4500731-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4499387-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4493970-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4493966-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4516903-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4516704-0 is absent or already exists, skip it
# 100%|██████████| 4/4 [00:00<00:00, 8443.49it/s]
# - document yahoo_bf029082-b1c9-449d-94d5-6839a08e6247 already exists, skip it
# - document nikkei_DGXZQOUC2018M0Q3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOUC136TL0T10C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUB00005_Q3A011C2000000 already exists, skip it
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Warning: Path '../data/6594.T_1130' exists, re-collect data again.
# Will download to: ../data/6594.T_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 11
# transcripts num_docs: 0
# Press Releases num_docs: 0
# news num_docs: 7
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 100%|██████████| 11/11 [00:00<00:00, 44620.26it/s]
# - document ubs_300661109 is absent or already exists, skip it
# - document ubs_300661108 is absent or already exists, skip it
# - document mq_ef3c2143-6acd-4e20-8d93-2bbe579e8001 is absent or already exists, skip it
# - document mq_322851e3-8683-4d1f-acea-4f0d2334ee6f is absent or already exists, skip it
# - document jf_394383 is absent or already exists, skip it
# - document jf_392421 is absent or already exists, skip it
# - document jf_396268 is absent or already exists, skip it
# - document jf_396278 is absent or already exists, skip it
# - document jf_396930 is absent or already exists, skip it
# - document jpmorgan_GPS-4515905-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4515021-0 is absent or already exists, skip it
# 100%|██████████| 7/7 [00:00<00:00, 35892.58it/s]
# - document yahoo_b83620fc-5891-3b70-b602-3ba49df9346a already exists, skip it
# - document yahoo_46bb8557-0fcd-388a-93f6-64ccb31b6b49 already exists, skip it
# - document nikkei_DGXZTSJC80401_X20C23A9000000 already exists, skip it
# - document nikkei_DGXZASFL27HYJ_X20C23A9000000 already exists, skip it
# - document nikkei_DGXZTSJC31001_S3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUF023LF0S3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUF05C0X0V01C23A0000000 already exists, skip it
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Warning: Path '../data/8316.T_1130' exists, re-collect data again.
# Will download to: ../data/8316.T_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 10
# transcripts num_docs: 0
# Press Releases num_docs: 0
# news num_docs: 16
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 100%|██████████| 10/10 [00:00<00:00, 44290.43it/s]
# - document ubs_300660050 is absent or already exists, skip it
# - document ubs_300660045 is absent or already exists, skip it
# - document mq_25c2207a-67e8-488d-b39b-070f98d8eed9 is absent or already exists, skip it
# - document mq_43b70886-61c6-4882-8c12-682b3abdc269 is absent or already exists, skip it
# - document jpmorgan_GPS-4501747-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4498241-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4519946-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4519816-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4525720-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4525654-0 is absent or already exists, skip it
# 100%|██████████| 16/16 [00:00<00:00, 59178.89it/s]
# - document yahoo_33d37eea-5b38-397e-bcbc-f178d64bb1cb already exists, skip it
# - document yahoo_4413e0d6-0102-3ede-8039-1640ce0cb6e7 already exists, skip it
# - document yahoo_a8b8ede4-2b25-3afd-ae21-f11191afeb8a already exists, skip it
# - document yahoo_481a6d53-ee59-3f36-88da-66a105089022 already exists, skip it
# - document yahoo_42048bb4-21cf-30dc-8d8c-d91cdc39ee8c already exists, skip it
# - document nikkei_DGXZQOUB052MC0V00C23A9000000 already exists, skip it
# - document nikkei_DGXZTSJT30401_S3A920C2000000 already exists, skip it
# - document nikkei_DGXZASFL22HUA_S3A920C2000000 already exists, skip it
# - document nikkei_DGXZTSJT80501_X20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS14_X20C23A9000000 already exists, skip it
# - document nikkei_DGXZASFL28H0W_Y3A920C2000000 already exists, skip it
# - document nikkei_DGXZNSD5ICP03_S3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUB057T50V01C23A0000000 already exists, skip it
# - document nikkei_DGXZASFL05H2G_V01C23A0000000 already exists, skip it
# - document nikkei_DGXZASFL10H10_Q3A011C2000000 already exists, skip it
# - document nikkei_DGXZASFL11H29_R11C23A0000000 already exists, skip it
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Warning: Path '../data/8411.T_1130' exists, re-collect data again.
# Will download to: ../data/8411.T_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 1
# transcripts num_docs: 0
# Press Releases num_docs: 0
# news num_docs: 5
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 100%|██████████| 1/1 [00:00<00:00, 11244.78it/s]
# - document jpmorgan_GPS-4515310-0 is absent or already exists, skip it
# 100%|██████████| 5/5 [00:00<00:00, 9328.97it/s]
# - document yahoo_f966af34-27e9-4322-8325-1ae0e38aded5 already exists, skip it
# - document yahoo_62921edd-738e-32ee-93fa-764d535f2ec1 already exists, skip it
# - document yahoo_f166e3ba-0156-3943-bfb0-16db46dad6ba already exists, skip it
# - document nikkei_DGXZASFL03HKI_T01C23A0000000 already exists, skip it
# - document nikkei_DGXZQOUB10CK50Q3A011C2000000 already exists, skip it
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Warning: Path '../data/8035.T_1130' exists, re-collect data again.
# Will download to: ../data/8035.T_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 17
# transcripts num_docs: 0
# Press Releases num_docs: 0
# news num_docs: 31
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 100%|██████████| 17/17 [00:00<00:00, 57179.77it/s]
# - document bt_177400 is absent or already exists, skip it
# - document bt_176294 is absent or already exists, skip it
# - document bt_178214 is absent or already exists, skip it
# - document ubs_300658588 is absent or already exists, skip it
# - document ubs_300658584 is absent or already exists, skip it
# - document mq_7afc7052-448d-43bb-a26f-9201f608cec5 is absent or already exists, skip it
# - document mq_934a3c97-9fde-4930-a776-2c271defe97c is absent or already exists, skip it
# - document mq_a21436db-e849-49c2-8117-1359b374cb78 is absent or already exists, skip it
# - document mq_3f5dec80-b5e1-4d33-a9d3-e5f3079d67c3 is absent or already exists, skip it
# - document mq_51feda67-fc3c-4763-800e-3962dae44fb1 is absent or already exists, skip it
# - document jf_391029 is absent or already exists, skip it
# - document jf_390569 is absent or already exists, skip it
# - document jf_385187 is absent or already exists, skip it
# - document jpmorgan_GPS-4465566-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4465564-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4519950-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4518958-0 is absent or already exists, skip it
# 100%|██████████| 31/31 [00:00<00:00, 69161.40it/s]
# - document yahoo_5b83e121-3876-344f-85bd-71defdaab3ec already exists, skip it
# - document yahoo_001cad63-b36a-325e-920d-e758754ce5ee already exists, skip it
# - document yahoo_ef8e05c2-f046-3543-b7fc-4ab71c5d91af already exists, skip it
# - document nikkei_DGXZAS3LTSEC1_Z10C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS13_S3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOUB250QY0V20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS16_V20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUC073LI0X00C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUB00005_W3A920C2000000 already exists, skip it
# - document nikkei_DGXZASFL26I2W_W3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS16_W3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS15_W3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS14_W3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS13_W3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS12_W3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS11_W3A920C2000000 already exists, skip it
# - document nikkei_DGXZASFL26HYG_W3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS16_X20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUB00004_X20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS12_X20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS16_Y3A920C2000000 already exists, skip it
# - document nikkei_DGXZQOUB00004_Y3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS14_Y3A920C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS14_Z20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS13_Z20C23A9000000 already exists, skip it
# - document nikkei_DGXZASS0ISS11_Z20C23A9000000 already exists, skip it
# - document nikkei_DGXZASFL06HZX_W3A001C2000000 already exists, skip it
# - document nikkei_DGXZASS0ISS16_W3A001C2000000 already exists, skip it
# - document nikkei_DGXZASFL06HDV_W3A001C2000000 already exists, skip it
# - document nikkei_DGXZASFL10HY7_Q3A011C2000000 already exists, skip it
# - document nikkei_DGXZASFL11HJB_R11C23A0000000 already exists, skip it
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Warning: Path '../data/6758.T_1130' exists, re-collect data again.
# Will download to: ../data/6758.T_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 13
# transcripts num_docs: 0
# Press Releases num_docs: 0
# news num_docs: 22
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 100%|██████████| 13/13 [00:00<00:00, 23706.94it/s]
# - document mq_072c82c0-c38c-4ec6-ae4e-56f41f9a79f5 is absent or already exists, skip it
# - document mq_545396ce-4e98-4647-85f8-faeada271d86 is absent or already exists, skip it
# - document jf_397186 is absent or already exists, skip it
# - document jpmorgan_GPS-4509236-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4509232-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4503233-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4503219-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4498375-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4497227-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4522870-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4522463-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4526667-0 is absent or already exists, skip it
# - document jpmorgan_GPS-4526663-0 is absent or already exists, skip it
# 100%|██████████| 22/22 [00:00<00:00, 34979.03it/s]
# - document yahoo_991f152f-8645-3ad5-8c5e-7c218576c3ea already exists, skip it
# - document yahoo_24a35b15-0600-4281-8916-96ae1b588872 already exists, skip it
# - document yahoo_483a4b95-ee59-4653-b794-a2bd43af93c2 already exists, skip it
# - document yahoo_bb0e04fa-51c2-32e6-add6-70b720c831f1 already exists, skip it
# - document yahoo_07ded14c-adb1-3eda-970d-ed616114b525 already exists, skip it
# - document yahoo_c29d60aa-5619-3336-bedd-924bc1d1ca3f already exists, skip it
# - document yahoo_617ece48-7b98-4741-8060-00597277469f already exists, skip it
# - document yahoo_d5981aed-3d07-3551-a181-4d72bf0dcc41 already exists, skip it
# - document yahoo_0d0f86f2-4274-44fc-b124-d0425a5e1fe4 already exists, skip it
# - document yahoo_c2c28ce7-45c8-35d4-9590-1377c89fa748 already exists, skip it
# - document yahoo_8b767f48-f3f4-388d-9849-3411eae50f18 already exists, skip it
# - document nikkei_DGXZQOUC1902B0Z10C23A9000000 already exists, skip it
# - document nikkei_DGXZASFL23H03_T20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUC275FP0X20C23A9000000 already exists, skip it
# - document nikkei_DGXZQOUC043RJ0U3A001C2000000 already exists, skip it
# - document nikkei_DGXZQOUB00004_T01C23A0000000 already exists, skip it
# - document nikkei_DGXZASS0ISS16_T01C23A0000000 already exists, skip it
# - document nikkei_DGXZQOUC114560R11C23A0000000 already exists, skip it
# - document nikkei_DGXZASS0ISS15_R11C23A0000000 already exists, skip it
# - document nikkei_DGXZQOUC110AG0R11C23A0000000 already exists, skip it
# ...
# - document cnbc_11e08f2c4381e93c3d528315d1b3eb78 already exists, skip it
# - document cnbc_8aee8b4eb8230e5f9dd0eba874e77172 already exists, skip it
# - document cnbc_7f431173a30ad0667528846209819b6c already exists, skip it
# - document cnbc_0c47c9b13268dbc45c4afa98e19e761d already exists, skip it
# - document cnbc_e1274dee37de807b1532587761abc7ca already exists, skip it
# - document cnbc_e908b7847d07be80555b6e22164aa053 already exists, skip it
# - document cnbc_91adde7bf4a8c0438c1d7d379f692416 already exists, skip it
# - document cnbc_107291997 already exists, skip it
# - document cnbc_cd62bf784fdf2bb22e5513860f5296d0 already exists, skip it
# - document cnbc_5a5579f3565f641172fa98664b0c6f5d already exists, skip it
# - document cnbc_8088767bddbf065832645348ea4104f5 already exists, skip it
# - document cnbc_257348e03348de0c969f00b9b55784fa already exists, skip it
# - document cnbc_21646e9d22a928603bccc7ffd673ac60 already exists, skip it
# - document cnbc_4c7ce4435425fb7f75707dac824e64fd already exists, skip it
# - document cnbc_d89a2d43ebfa6b54ee01d1cac48e465e already exists, skip it
# - document cnbc_b5af43031be475b4c9ec88b40ceb1a6c already exists, skip it
# - document cnbc_6faae0658acac190e6b929c5157e5924 already exists, skip it
# - document cnbc_69ea49db486b8580d43dd5917eebe245 already exists, skip it
# - document cnbc_5c46887006b7576efb292f3f0e804a75 already exists, skip it
# - document cnbc_267c9f5fa8043b083da37f847009819d already exists, skip it
# - document cnbc_4c8105137d90b1c94614acb29d368b63 already exists, skip it
# - document cnbc_e2c39581f927894fb8efb8ea0c9a6e1e already exists, skip it
# - document cnbc_8ee229a6308df2b744aa715068445d72 already exists, skip it
# - document cnbc_fe3048b35b24c792a32348ebea53a9e7 already exists, skip it
# - document cnbc_420d3ebf0e56b9be178539786f0ccd65 already exists, skip it
# - document cnbc_5102f5f9c6a951e90590a3c60a0f14ee already exists, skip it
# - document cnbc_0989cc6c42237169c31107e1312f7484 already exists, skip it
# - document cnbc_74c22b1ff4e3b9b2bcf2763f823826e9 already exists, skip it
# - document cnbc_e461970226d2822b60e074ad4b7ea2db already exists, skip it
# - document cnbc_c71f4872e82f90284984b0108494c0d4 already exists, skip it
# - document cnbc_d0e2bf74f3afa245fc82c7150b752bee already exists, skip it
# - document cnbc_6f6e75de67ceee1c9980e275ee5e1420 already exists, skip it
# - document cnbc_2e02cc760a6a04c94ffcca7d739e157f already exists, skip it
# - document cnbc_169636cd2db1d3e8b9fffad4494b33c4 already exists, skip it
# - document cnbc_107300492 already exists, skip it
# - document cnbc_3fa3fb8995db19cc15fc011c39b0241e already exists, skip it
# - document cnbc_91ffbbaf31f393f44fdd78d7514154af already exists, skip it
# - document cnbc_c007f8a04ed41b7cafa4d2fb6c0ed381 already exists, skip it
# - document cnbc_f03718d710f0cb2b2e6f5fc0fa0dfa5f already exists, skip it
# - document cnbc_eaa47dec7d0abc5228d354358985ca1e already exists, skip it
# - document cnbc_5b996eee7921c032f37e5621ca16da7f already exists, skip it
# - document cnbc_3c975b010a20b500460b2c70bf83afbe already exists, skip it
# - document cnbc_e3604f6eac0546ac4f69c54620cbb0e6 already exists, skip it
# - document cnbc_6517a5ddfac7e249b7cad2e11b58a54d already exists, skip it
# - document cnbc_3c1132dd4c90d7536e547c3ea79569fb already exists, skip it
# - document cnbc_3d8792f5e9e127fb86cdf495cb8ae9f0 already exists, skip it
# - document cnbc_d2a82c3cbf6c964b61c27b11a82414c6 already exists, skip it
# - document cnbc_e6c12903e7f027eebd0c2a7292ad2e52 already exists, skip it
# - document cnbc_71b3f2afccd0ad379092e89c56a30640 already exists, skip it
# - document cnbc_7f1ea3de7a14935187f76ef7463346a7 already exists, skip it
# - document cnbc_0e967571bd351a78764d1c9f29c8102f already exists, skip it
# - document cnbc_d2511acaa4f39ae30b12c5857fa5b3fe already exists, skip it
# - document cnbc_4501c7009413f5b1c305afa4d034f7c8 already exists, skip it
# - document cnbc_2858bc86fd47f1fccc5a59b9329b1e07 already exists, skip it
# - document cnbc_8ce5ad84df1c3868082ceb7a7c90b6d6 already exists, skip it
# - document cnbc_1a584cb960536681f9c63e1558efb3d2 already exists, skip it
# - document cnbc_5acb0c92107c4c0ca7500a0972985cfd already exists, skip it
# - document cnbc_b4a69d17b7de2c8d51ec6d4d38296766 already exists, skip it
# - document cnbc_dc6be27d1b2ffddbbdb75381f9335034 already exists, skip it
# - document cnbc_3ac268ec6702ffc613fc878fc631e1f9 already exists, skip it
# - document cnbc_beac9cbe4aa1f26bdcb67136421ee54f already exists, skip it
# - document cnbc_cb080b9d514dbc11498863b38f729a83 already exists, skip it
# - document cnbc_107315541 already exists, skip it
# - document cnbc_336c88780e7d5d0d7ebcced26afb9be7 already exists, skip it
# - document cnbc_0aeb1d27d06836437adedd79eda179e0 already exists, skip it
# - document cnbc_00c8771a57391bad3fbd819f16197cd3 already exists, skip it
# - document cnbc_73b63a835c505f2182ce71a3eea34f64 already exists, skip it
# - document cnbc_107316690 already exists, skip it
# - document cnbc_7182795e53a6ea10d4f21e661d3108a6 already exists, skip it
# - document cnbc_ffb0097c9a6f42a25fc9b0869d656d07 already exists, skip it
# - document cnbc_3ac42b9c81443a6ad3a8ee596693c0aa already exists, skip it
# - document cnbc_fed78d2609ce514fefd7bab2aea28cb7 already exists, skip it
# - document cnbc_60cd43dd4165ccd7caaaaf34f41633f4 already exists, skip it
# - document cnbc_d02b3c39ae93fb2a2bfcc17633c3d616 already exists, skip it
# - document cnbc_107316644 already exists, skip it
# - document cnbc_2bbac0bb972b8c1c425bf73b39c8098c already exists, skip it
# - document cnbc_dee00752c204cfceed6848a58492f811 already exists, skip it
# - document cnbc_473e0993d1192d42b892fd318c7c92a6 already exists, skip it
# - document cnbc_00160778241429eb41b328f42cdc9cf3 already exists, skip it
# - document cnbc_3182db46416d85a41765c25e35b5c338 already exists, skip it
# - document cnbc_3c11ef54b2a5030a76c012ef87f5f04a already exists, skip it
# - document cnbc_c94d610025503819de952415b91d43ab already exists, skip it
# - document cnbc_9e36b8b0e21a587cc441fe8e3225c224 already exists, skip it
# - document cnbc_8d7d9fe7609e79131831a24692364e67 already exists, skip it
# - document cnbc_569a26d353a10bf1497da976cc879a28 already exists, skip it
# - document cnbc_16a1fbfaa834d104b7db1dc1f868cb34 already exists, skip it
# - document cnbc_dd761d82f2d64e53b4421c44b53cdaaf already exists, skip it
# - document cnbc_107319152 already exists, skip it
# - document cnbc_107318769 already exists, skip it
# - document cnbc_4fc788d7994be123611ebbf61a48121b already exists, skip it
# - document cnbc_107318749 already exists, skip it
# - document cnbc_b22111338bdf1cafc0b303907ca9bba9 already exists, skip it
# - document cnbc_107319582 already exists, skip it
# - document cnbc_107319555 already exists, skip it
# - document cnbc_dc5a5123220945138605cb0abcc92a42 already exists, skip it
# - document cnbc_05ae7aa379b80c72e249611450afc2af already exists, skip it
# - document cnbc_39b421d89bd7d130d5684a50a026c015 already exists, skip it
# - document cnbc_7900f05577e399ed07597a88a7f88ef4 already exists, skip it
# - document cnbc_572de074562c0cb9516ae9e8a19a316d already exists, skip it
# - document cnbc_d23a17169db735f04f5e15449b945d14 already exists, skip it
# - document cnbc_d9b756f92be7a5b1dd77f1c501d53dd4 already exists, skip it
# - document cnbc_db1f4268d62a64253907a585f8135db1 already exists, skip it
# - document cnbc_107319795 already exists, skip it
# - document cnbc_107319996 already exists, skip it
# - document cnbc_107319880 already exists, skip it
# - document cnbc_ed7b167d53232aa0d6a66e8f5132eedb already exists, skip it
# - document cnbc_01f1741921cfdf699e643e87d4414f1e already exists, skip it
# - document cnbc_107320010 already exists, skip it
# - document cnbc_6ba97f05c888333a134df2f0c397120f already exists, skip it
# - document cnbc_97d5081e2a8f9fb1202936726ca82698 already exists, skip it
# - document cnbc_15870e393f538d250e4113997992ad27 already exists, skip it
# - document cnbc_937bb1f410e10f4bbf6ab603c26ed94c already exists, skip it
# - document cnbc_993a68f22e62bd43a0d32f25cd21a33c already exists, skip it
# - document cnbc_b83f11fb3bc7f2dd7fa2da3af1e6ad9c already exists, skip it
# - document cnbc_3d2600916910e8fda2b4b258c04484c7 already exists, skip it
# - document cnbc_77a877f55b3b4468ed884320847500ee already exists, skip it
# - document cnbc_8d64c0faea4265088b8d9d0b0ef79f77 already exists, skip it
# - document cnbc_3a8e2e971cbc9db5094a83b2dfec26fa already exists, skip it
# - document cnbc_ec274b0e932a32468bb69bee970927c1 already exists, skip it
# - document cnbc_b980501fccb0262493b79d4e8338ffb8 already exists, skip it
# - document cnbc_25c08261319f652e49e24169cb2acba7 already exists, skip it
# - document cnbc_04b51726d35f8218e6dbadd2286aec80 already exists, skip it
# - document cnbc_d535a3e219756953a3ecfb0dc9952cad already exists, skip it
# - document cnbc_01cc2ad65ecf67df4520b7e71c84b00f already exists, skip it
# - document cnbc_ab1543abc9d04904058396ef6a0e734d already exists, skip it
# - document cnbc_e2006080a4a049b683b1d328cc4a2b20 already exists, skip it
# - document cnbc_859e76cb44cc275f7777f0e3a210c33c already exists, skip it
# - document cnbc_1434e47d186153e42daf34f5f6e40267 already exists, skip it
# - document cnbc_453aa20ca87822518dc82e0a9db23165 already exists, skip it
# - document cnbc_107308593 already exists, skip it
# - document cnbc_107326880 already exists, skip it
# - document cnbc_6d4976cb0a1960fb1a8e39d5f87385d5 already exists, skip it
# - document cnbc_ace556738b44df25018d8ed95e454c1e already exists, skip it
# - document cnbc_96f1b68aa3293cea6e1e25c4e421907f already exists, skip it
# - document cnbc_0dced535468f61417b23ffe8ad061217 already exists, skip it
# - document cnbc_b4c85c4b6daf0a5f5f50b6ac9a97d78b already exists, skip it
# - document cnbc_107331449 already exists, skip it
# - document cnbc_ea6f5da4647dc091fa915eb246b71f21 already exists, skip it
# - document cnbc_e9219ece77e6d082d6cd967ab96dcea5 already exists, skip it
# - document cnbc_40a0cf09da052ca08c5ce6ec4db23454 already exists, skip it
# - document cnbc_ec9bbfa60e07f261f514db53e60230bb already exists, skip it
# - document cnbc_107340770 already exists, skip it
# - document cnbc_2554ca924ea7d1e1ab1b4c6198956ca0 already exists, skip it
# - document cnbc_6b71dce7551d8d94fb393f332c714756 already exists, skip it
# - document cnbc_e95e16472e97641cdc78ad4c4e0ba55b already exists, skip it
# - document cnbc_8e54a9ffe0f4f233b985993b72d0754d already exists, skip it
# - document cnbc_635758922af7287c2bbca532479f148a already exists, skip it
# - document cnbc_107343244 already exists, skip it
# - document cnbc_4a89155ada49b6b9f184d3bab641c575 already exists, skip it
# - document wsj_638257945200000000 already exists, skip it
# - document wsj_638318340000000000 already exists, skip it
# - document wsj_638319234600000000 already exists, skip it
# - document wsj_638319313200000000 already exists, skip it
# - document wsj_638319408000000000 already exists, skip it
# - document wsj_638319469800000000 already exists, skip it
# - document wsj_638330310000000000 already exists, skip it
# - document wsj_638330472000000000 already exists, skip it
# - document wsj_638330586600000000 already exists, skip it
# - document wsj_638332421400000000 already exists, skip it
# - document wsj_638332452000000000 already exists, skip it
# - document wsj_638332902000000000 already exists, skip it
# 100%|██████████| 2/2 [00:00<00:00, 29537.35it/s]
# - document sAts_4618237 already exists, skip it
# - document sAts_4641691 already exists, skip it
# 100%|██████████| 2/2 [00:00<00:00, 30283.78it/s]
# - document 8-K_a393ec5f7c66814901859ebe23f80249 already exists, skip it
# - document 8-K_9c36b37de9ab0943e631c79acfdd9cd2 already exists, skip it
# Warning: Path '../data/LVS.N_1130' exists, re-collect data again.
# Will download to: ../data/LVS.N_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 0
# transcripts num_docs: 2
# Press Releases num_docs: 2
# news num_docs: 0
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00, 8405.42it/s]
# - document sAts_4618238 already exists, skip it
# - document sAts_4641693 already exists, skip it
# 100%|██████████| 2/2 [00:00<00:00, 11831.61it/s]
# - document 8-K_9a5e3f1260f8b1045fe105082317fb09 already exists, skip it
# - document 8-K_f684bf8176795526cfbf3b4b97154176 already exists, skip it
# Warning: Path '../data/IBM.N_1130' exists, re-collect data again.
# Will download to: ../data/IBM.N_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
# Collecting: news -> news -> cnbc_contents
# Collecting: news -> news -> news_jp_nikkei_contents
# Collecting: news -> news -> wsj_contents
# Collecting: research -> website -> bernste
# Collecting: research -> website -> neoubs
# Collecting: research -> website -> aletheia
# Collecting: research -> website -> marquee
# Collecting: research -> website -> jefferies
# Collecting: research -> website -> jpmorgan
# Collecting: research -> email -> emailContents
# Collecting: research -> website -> yipit
# Collecting: research -> website -> east
# Collecting: research -> website -> cicc
# research num_docs: 0
# transcripts num_docs: 1
# Press Releases num_docs: 1
# news num_docs: 22
# tables num_docs: 0
# Collecting research pdfs/htmls ...
# Finish.
# 0it [00:00, ?it/s]
# 100%|██████████| 22/22 [00:00<00:00, 91907.06it/s]
# - document sA_4021488 already exists, skip it
# - document sA_4038053 already exists, skip it
# - document sA_4042721 already exists, skip it
# - document sA_4043062 already exists, skip it
# - document sA_4043214 already exists, skip it
# - document benzinga_35266496 already exists, skip it
# - document benzinga_35854972 already exists, skip it
# - document benzinga_36085130 already exists, skip it
# - document cnbc_0e5c4f54ade23f4ce27c6aebb7bd9023 already exists, skip it
# - document cnbc_a62da1f4ae6a06f1d085845b1cc04c21 already exists, skip it
# - document cnbc_3318fa8e26fd94cf198f94a8799918b3 already exists, skip it
# - document cnbc_4dbecd290df64a7e6e1826bc1d29f7de already exists, skip it
# - document cnbc_f5fbf7c1b7f5061b2067ad79d89d75bd already exists, skip it
# - document cnbc_3b1e9652e643e392f23167e5d2ff8205 already exists, skip it
# - document cnbc_eeaed6614b1fccbe29c49eb4b8414a97 already exists, skip it
# - document cnbc_e9c68371b926a113f828f83a8462a663 already exists, skip it
# - document cnbc_f94b6a41389140a0cf5ef5a5756551ef already exists, skip it
# - document cnbc_107335309 already exists, skip it
# - document cnbc_31219fb16d7165bbd755b169dd31fb9f already exists, skip it
# - document cnbc_cdac882b180eca00e4b7a31c2298bca6 already exists, skip it
# - document cnbc_294617679688feab02b52a26fc7058e8 already exists, skip it
# - document cnbc_90ca76a1c327a23eba30a17801263d6b already exists, skip it
# 100%|██████████| 1/1 [00:00<00:00, 9098.27it/s]
# - document sAts_4618244 already exists, skip it
# 100%|██████████| 1/1 [00:00<00:00, 12557.80it/s]
# - document 8-K_7ae4a8eab82907f78e2a92ca4c24949b already exists, skip it
# Warning: Path '../data/TSLA.O_1130' exists, re-collect data again.
# Will download to: ../data/TSLA.O_1130
# Collecting: news -> news -> yahoo_contetns_jp
# Collecting: transcripts -> website -> transcripts
# Collecting: Press Releases -> website -> 8-K_data
# Collecting: news -> news -> news_contents
# Collecting: news -> news -> benzinga_contents
